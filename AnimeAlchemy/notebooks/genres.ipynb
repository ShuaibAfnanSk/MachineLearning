# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('anime.csv')
df1
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df2 = pd.read_csv('anime_with_synopsis.csv')
df2
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16211   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df = df1.merge(df2,on='MAL_ID')

# %%
df = df[['MAL_ID','Name_x','Genres_x','sypnopsis','Type','Producers','Licensors','Studios','Score_x','Source']]

# %%
df['Name'] = df['Name_x']
df['Score'] = df['Score_x']
df['Genre'] = df['Genres_x']
df['Synopsis'] = df['sypnopsis']
df = df.drop(['Name_x','Genres_x','Score_x','sypnopsis'],axis=1)

# %%
df = df.dropna()

# %%
df['Comedy'] = df['Genre'].apply(lambda x:x.find('Comedy'))
df['Action'] = df['Genre'].apply(lambda x:x.find('Action'))
df['Sci-Fi'] = df['Genre'].apply(lambda x:x.find('Sci-Fi'))
df['Romance'] = df['Genre'].apply(lambda x:x.find('Romance'))
df['Mecha'] = df['Genre'].apply(lambda x:x.find('Mecha'))
df['Sports'] = df['Genre'].apply(lambda x:x.find('Sports'))
df['Drama'] = df['Genre'].apply(lambda x:x.find('Drama'))
df['Supernatural'] = df['Genre'].apply(lambda x:x.find('Supernatural'))
df['Adventure'] = df['Genre'].apply(lambda x:x.find('Adventure'))
df['Fear'] = df['Genre'].apply(lambda x:x.find('Horror'))
df['Surprised'] = df['Genre'].apply(lambda x:x.find('Mystery'))

# %%
df_comedy = df[df['Comedy'] >= 0]
df_action = df[df['Action'] >= 0]
df_scifi = df[df['Sci-Fi'] >= 0]
df_romance = df[df['Romance'] >= 0]
df_mecha = df[df['Mecha'] >= 0]
df_sports = df[df['Sports'] >= 0]
df_drama = df[df['Drama'] >= 0]
df_supernatural = df[df['Supernatural'] >= 0]
df_adventure = df[df['Adventure'] >= 0]
df_fear = df[df['Fear'] >= 0]
df_surprised = df[df['Surprised'] >= 0]

# %%
print(df_comedy.shape,
df_action.shape,
df_scifi.shape,
df_romance.shape,
df_mecha.shape,
df_sports.shape,
df_drama.shape, 
df_supernatural.shape,
df_adventure.shape)
# Out:
# (5971, 19) (3846, 19) (2550, 19) (1852, 19) (1094, 19) (708, 19) (2589, 19) (1409, 19) (2942, 19)

# %%
df_comedy
# Out:
#        MAL_ID     Type                                          Producers  \
# 0           1       TV                                      Bandai Visual
# 2           6       TV                               Victor Entertainment
# 5          15       TV  TV Tokyo, Nihon Ad Systems, TV Tokyo Music, Sh...
# 6          16       TV                           Genco, Fuji TV, Shueisha
# 7          17       TV                                            Unknown
# ...       ...      ...                                                ...
# 16193   48413       TV                                            Unknown
# 16199   48426    Movie                                            Unknown
# 16204   48456  Special                      Aniplex, Movic, ABC Animation
# 16210   48483       TV                                           Kadokawa
# 16212   48491       TV                                           Kadokawa
#
#                                   Licensors           Studios       Source  \
# ...

# %%
df_comedy = df_comedy.iloc[:,0:10]
df_action = df_action.iloc[:,0:10]
df_scifi = df_scifi.iloc[:,0:10]
df_sports = df_sports.iloc[:,0:10]
df_supernatural = df_supernatural.iloc[:,0:10]
df_romance = df_romance.iloc[:,0:10]
df_drama = df_drama.iloc[:,0:10]
df_mecha = df_mecha.iloc[:,0:10]
df_adventure= df_adventure.iloc[:,0:10]
df_surprised = df_surprised.iloc[:,0:10]
df_fear = df_fear.iloc[:,0:10]

# %%
print(df_comedy.shape,
df_action.shape,
df_scifi.shape,
df_romance.shape,
df_mecha.shape,
df_sports.shape,
df_drama.shape, 
df_supernatural.shape,
df_adventure.shape)
# Out:
# (5971, 10) (3846, 10) (2550, 10) (1852, 10) (1094, 10) (708, 10) (2589, 10) (1409, 10) (2942, 10)

# %%
df_surprised['Source'] = df_surprised['Source'].str.replace('Original','Source : Original ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Manga','Source : Manga ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Light novel','Source : Light novel ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Game','Source : Game ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Visual novel','Source : Visual novel ')
df_surprised['Source'] = df_surprised['Source'].str.replace('4-koma manga','Source : 4-koma manga ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Unknown','Source : Unknown ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Picture book','Source : Picture book ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Web manga','Source : Web manga ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Music','Source : Music ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Radio','Source : Radio ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Book','Source : Book ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Card game','Source : Card game ')
df_surprised['Source'] = df_surprised['Source'].str.replace('Digital manga','Source : Digital manga ')

# %%
df_fear['Source'] = df_fear['Source'].str.replace('Original','Source : Original ')
df_fear['Source'] = df_fear['Source'].str.replace('Manga','Source : Manga ')
df_fear['Source'] = df_fear['Source'].str.replace('Light novel','Source : Light novel ')
df_fear['Source'] = df_fear['Source'].str.replace('Game','Source : Game ')
df_fear['Source'] = df_fear['Source'].str.replace('Visual novel','Source : Visual novel ')
df_fear['Source'] = df_fear['Source'].str.replace('4-koma manga','Source : 4-koma manga ')
df_fear['Source'] = df_fear['Source'].str.replace('Unknown','Source : Unknown ')
df_fear['Source'] = df_fear['Source'].str.replace('Picture book','Source : Picture book ')
df_fear['Source'] = df_fear['Source'].str.replace('Web manga','Source : Web manga ')
df_fear['Source'] = df_fear['Source'].str.replace('Music','Source : Music ')
df_fear['Source'] = df_fear['Source'].str.replace('Radio','Source : Radio ')
df_fear['Source'] = df_fear['Source'].str.replace('Book','Source : Book ')
df_fear['Source'] = df_fear['Source'].str.replace('Card game','Source : Card game ')
df_fear['Source'] = df_fear['Source'].str.replace('Digital manga','Source : Digital manga ')

# %%
df_comedy['Source'] = df_comedy['Source'].str.replace('Original','Source : Original ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Manga','Source : Manga ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Light novel','Source : Light novel ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Game','Source : Game ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Visual novel','Source : Visual novel ')
df_comedy['Source'] = df_comedy['Source'].str.replace('4-koma manga','Source : 4-koma manga ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Unknown','Source : Unknown ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Picture book','Source : Picture book ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Web manga','Source : Web manga ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Music','Source : Music ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Radio','Source : Radio ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Book','Source : Book ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Card game','Source : Card game ')
df_comedy['Source'] = df_comedy['Source'].str.replace('Digital manga','Source : Digital manga ')

# %%
df_adventure['Source'] = df_adventure['Source'].str.replace('Original','Source : Original ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Manga','Source : Manga ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Light novel','Source : Light novel ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Game','Source : Game ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Visual novel','Source : Visual novel ')
df_adventure['Source'] = df_adventure['Source'].str.replace('4-koma manga','Source : 4-koma manga ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Unknown','Source : Unknown ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Picture book','Source : Picture book ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Web manga','Source : Web manga ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Music','Source : Music ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Radio','Source : Radio ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Book','Source : Book ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Card game','Source : Card game ')
df_adventure['Source'] = df_adventure['Source'].str.replace('Digital manga','Source : Digital manga ')

# %%
df_action['Source'] = df_action['Source'].str.replace('Original','Source : Original ')
df_action['Source'] = df_action['Source'].str.replace('Manga','Source : Manga ')
df_action['Source'] = df_action['Source'].str.replace('Light novel','Source : Light novel ')
df_action['Source'] = df_action['Source'].str.replace('Game','Source : Game ')
df_action['Source'] = df_action['Source'].str.replace('Visual novel','Source : Visual novel ')
df_action['Source'] = df_action['Source'].str.replace('4-koma manga','Source : 4-koma manga ')
df_action['Source'] = df_action['Source'].str.replace('Unknown','Source : Unknown ')
df_action['Source'] = df_action['Source'].str.replace('Picture book','Source : Picture book ')
df_action['Source'] = df_action['Source'].str.replace('Web manga','Source : Web manga ')
df_action['Source'] = df_action['Source'].str.replace('Music','Source : Music ')
df_action['Source'] = df_action['Source'].str.replace('Radio','Source : Radio ')
df_action['Source'] = df_action['Source'].str.replace('Book','Source : Book ')
df_action['Source'] = df_action['Source'].str.replace('Card game','Source : Card game ')
df_action['Source'] = df_action['Source'].str.replace('Digital manga','Source : Digital manga ')

# %%
df_scifi['Source'] = df_scifi['Source'].str.replace('Original','Source : Original ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Manga','Source : Manga ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Light novel','Source : Light novel ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Game','Source : Game ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Visual novel','Source : Visual novel ')
df_scifi['Source'] = df_scifi['Source'].str.replace('4-koma manga','Source : 4-koma manga ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Unknown','Source : Unknown ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Picture book','Source : Picture book ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Web manga','Source : Web manga ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Music','Source : Music ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Radio','Source : Radio ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Book','Source : Book ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Card game','Source : Card game ')
df_scifi['Source'] = df_scifi['Source'].str.replace('Digital manga','Source : Digital manga ')

# %%
df_drama['Source'] = df_drama['Source'].str.replace('Original','Source : Original ')
df_drama['Source'] = df_drama['Source'].str.replace('Manga','Source : Manga ')
df_drama['Source'] = df_drama['Source'].str.replace('Light novel','Source : Light novel ')
df_drama['Source'] = df_drama['Source'].str.replace('Game','Source : Game ')
df_drama['Source'] = df_drama['Source'].str.replace('Visual novel','Source : Visual novel ')
df_drama['Source'] = df_drama['Source'].str.replace('4-koma manga','Source : 4-koma manga ')
df_drama['Source'] = df_drama['Source'].str.replace('Unknown','Source : Unknown ')
df_drama['Source'] = df_drama['Source'].str.replace('Picture book','Source : Picture book ')
df_drama['Source'] = df_drama['Source'].str.replace('Web manga','Source : Web manga ')
df_drama['Source'] = df_drama['Source'].str.replace('Music','Source : Music ')
df_drama['Source'] = df_drama['Source'].str.replace('Radio','Source : Radio ')
df_drama['Source'] = df_drama['Source'].str.replace('Book','Source : Book ')
df_drama['Source'] = df_drama['Source'].str.replace('Card game','Source : Card game ')
df_drama['Source'] = df_drama['Source'].str.replace('Digital manga','Source : Digital manga ')

# %%
df_romance['Source'] = df_romance['Source'].str.replace('Original','Source : Original ')
df_romance['Source'] = df_romance['Source'].str.replace('Manga','Source : Manga ')
df_romance['Source'] = df_romance['Source'].str.replace('Light novel','Source : Light novel ')
df_romance['Source'] = df_romance['Source'].str.replace('Game','Source : Game ')
df_romance['Source'] = df_romance['Source'].str.replace('Visual novel','Source : Visual novel ')
df_romance['Source'] = df_romance['Source'].str.replace('4-koma manga','Source : 4-koma manga ')
df_romance['Source'] = df_romance['Source'].str.replace('Unknown','Source : Unknown ')
df_romance['Source'] = df_romance['Source'].str.replace('Picture book','Source : Picture book ')
df_romance['Source'] = df_romance['Source'].str.replace('Web manga','Source : Web manga ')
df_romance['Source'] = df_romance['Source'].str.replace('Music','Source : Music ')
df_romance['Source'] = df_romance['Source'].str.replace('Radio','Source : Radio ')
df_romance['Source'] = df_romance['Source'].str.replace('Book','Source : Book ')
df_romance['Source'] = df_romance['Source'].str.replace('Card game','Source : Card game ')
df_romance['Source'] = df_romance['Source'].str.replace('Digital manga','Source : Digital manga ')

# %%
df_mecha['Source'] = df_mecha['Source'].str.replace('Original','Source : Original ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Manga','Source : Manga ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Light novel','Source : Light novel ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Game','Source : Game ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Visual novel','Source : Visual novel ')
df_mecha['Source'] = df_mecha['Source'].str.replace('4-koma manga','Source : 4-koma manga ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Unknown','Source : Unknown ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Picture book','Source : Picture book ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Web manga','Source : Web manga ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Music','Source : Music ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Radio','Source : Radio ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Book','Source : Book ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Card game','Source : Card game ')
df_mecha['Source'] = df_mecha['Source'].str.replace('Digital manga','Source : Digital manga ')

# %%
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Original','Source : Original ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Manga','Source : Manga ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Light novel','Source : Light novel ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Game','Source : Game ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Visual novel','Source : Visual novel ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('4-koma manga','Source : 4-koma manga ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Unknown','Source : Unknown ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Picture book','Source : Picture book ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Web manga','Source : Web manga ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Music','Source : Music ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Radio','Source : Radio ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Book','Source : Book ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Card game','Source : Card game ')
df_supernatural['Source'] = df_supernatural['Source'].str.replace('Digital manga','Source : Digital manga ')

# %%
df_sports['Source'] = df_sports['Source'].str.replace('Original','Source : Original ')
df_sports['Source'] = df_sports['Source'].str.replace('Manga','Source : Manga ')
df_sports['Source'] = df_sports['Source'].str.replace('Light novel','Source : Light novel ')
df_sports['Source'] = df_sports['Source'].str.replace('Game','Source : Game ')
df_sports['Source'] = df_sports['Source'].str.replace('Visual novel','Source : Visual novel ')
df_sports['Source'] = df_sports['Source'].str.replace('4-koma manga','Source : 4-koma manga ')
df_sports['Source'] = df_sports['Source'].str.replace('Unknown','Source : Unknown ')
df_sports['Source'] = df_sports['Source'].str.replace('Picture book','Source : Picture book ')
df_sports['Source'] = df_sports['Source'].str.replace('Web manga','Source : Web manga ')
df_sports['Source'] = df_sports['Source'].str.replace('Music','Source : Music ')
df_sports['Source'] = df_sports['Source'].str.replace('Radio','Source : Radio ')
df_sports['Source'] = df_sports['Source'].str.replace('Book','Source : Book ')
df_sports['Source'] = df_sports['Source'].str.replace('Card game','Source : Card game ')
df_sports['Source'] = df_sports['Source'].str.replace('Digital manga','Source : Digital manga ')

# %%
df_comedy['tags'] = df_comedy['Synopsis']+df_comedy['Genre']+df_comedy['Studios']+df_comedy['Producers']+df_comedy['Licensors']
df_drama['tags'] = df_drama['Synopsis']+df_drama['Genre']+df_drama['Studios']+df_drama['Producers']+df_drama['Licensors']
df_supernatural['tags'] = df_supernatural['Synopsis']+df_supernatural['Genre']+df_supernatural['Studios']+df_supernatural['Producers']+df_supernatural['Licensors']
df_romance['tags'] = df_romance['Synopsis']+df_romance['Genre']+df_romance['Studios']+df_romance['Producers']+df_romance['Licensors']
df_mecha['tags'] = df_mecha['Synopsis']+df_mecha['Genre']+df_mecha['Studios']+df_mecha['Producers']+df_mecha['Licensors']
df_sports['tags'] = df_sports['Synopsis']+df_sports['Genre']+df_sports['Studios']+df_sports['Producers']+df_sports['Licensors']
df_action['tags'] = df_action['Synopsis']+df_action['Genre']+df_action['Studios']+df_action['Producers']+df_action['Licensors']
df_scifi['tags'] = df_scifi['Synopsis']+df_scifi['Genre']+df_scifi['Studios']+df_scifi['Producers']+df_scifi['Licensors']
df_adventure['tags'] = df_adventure['Synopsis']+df_adventure['Genre']+df_adventure['Studios']+df_adventure['Producers']+df_adventure['Licensors']

# %%
df_fear['tags'] = df_fear['Synopsis']+df_fear['Genre']+df_fear['Studios']+df_fear['Producers']+df_fear['Licensors']
df_surprised['tags'] = df_surprised['Synopsis']+df_surprised['Genre']+df_surprised['Studios']+df_surprised['Producers']+df_surprised['Licensors']
Fear = df_fear[['MAL_ID','Name','tags','Score','Type']]
Surprised = df_surprised[['MAL_ID','Name','tags','Score','Type']]

# %%
Comedy = df_comedy[['MAL_ID','Name','tags','Score','Type']]
Action = df_action[['MAL_ID','Name','tags','Score','Type']]
SciFi = df_scifi[['MAL_ID','Name','tags','Score','Type']]
Sports = df_sports[['MAL_ID','Name','tags','Score','Type']]
Supernatural = df_supernatural[['MAL_ID','Name','tags','Score','Type']]
Romance = df_romance[['MAL_ID','Name','tags','Score','Type']]
Drama = df_drama[['MAL_ID','Name','tags','Score','Type']]
Mecha = df_mecha[['MAL_ID','Name','tags','Score','Type']]
Adventure = df_adventure[['MAL_ID','Name','tags','Score','Type']]

# %%
Comedy['tags'] = Comedy['tags'].str.replace(',','')
Comedy['tags'] = Comedy['tags'].map(str.lower)
Action['tags'] = Action['tags'].str.replace(',','')
Action['tags'] = Action['tags'].map(str.lower)
Sports['tags'] = Sports['tags'].str.replace(',','')
Sports['tags'] = Sports['tags'].map(str.lower)
SciFi['tags'] = SciFi['tags'].str.replace(',','')
SciFi['tags'] = SciFi['tags'].map(str.lower)
Supernatural['tags'] = Supernatural['tags'].str.replace(',','')
Supernatural['tags'] = Supernatural['tags'].map(str.lower)
Romance['tags'] = Romance['tags'].str.replace(',','')
Romance['tags'] = Romance['tags'].map(str.lower)
Drama['tags'] = Drama['tags'].str.replace(',','')
Drama['tags'] = Drama['tags'].map(str.lower)
Mecha['tags'] = Mecha['tags'].str.replace(',','')
Mecha['tags'] = Mecha['tags'].map(str.lower)
Adventure['tags'] = Adventure['tags'].str.replace(',','')
Adventure['tags'] = Adventure['tags'].map(str.lower)
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\2047159089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Comedy['tags'] = Comedy['tags'].str.replace(',','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\2047159089.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Comedy['tags'] = Comedy['tags'].map(str.lower)
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\2047159089.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Fear['tags'] = Fear['tags'].str.replace(',','')
Fear['tags'] = Fear['tags'].map(str.lower)
Surprised['tags'] = Surprised['tags'].str.replace(',','')
Surprised['tags'] = Surprised['tags'].map(str.lower)
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1676\4078990615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fear['tags'] = Fear['tags'].str.replace(',','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1676\4078990615.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fear['tags'] = Fear['tags'].map(str.lower)
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1676\4078990615.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Comedy
# Out:
#        MAL_ID                            Name  \
# 0           1                    Cowboy Bebop
# 2           6                          Trigun
# 5          15                    Eyeshield 21
# 6          16            Hachimitsu to Clover
# 7          17      Hungry Heart: Wild Striker
# ...       ...                             ...
# 16193   48413  Hataraku Maou-sama! 2nd Season
# 16199   48426  Kitarou Tanjou: Gegege no Nazo
# 16204   48456             SK∞: Crazy Rock Jam
# 16210   48483                    Mieruko-chan
# 16212   48491     Yama no Susume: Next Summit
#
#                                                     tags    Score     Type
# 0      in the year 2071 humanity has colonized severa...     8.78       TV
# 2      vash the stampede is the man with a $$60000000...     8.24       TV
# 5      sena is like any other shy kid starting high s...     7.95       TV
# 6      yuuta takemoto a sophomore at an arts college ...     8.06       TV
# ...

# %%
Action['Score'] = Action['Score'].str.replace('Unknown','')
Action['Score'] = Action['Score'].replace(r'^\s*$', np.nan, regex=True)
Action = Action.dropna()
Action = Action.sort_values(ascending=False,by='Score')
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\2306927867.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Action['Score'] = Action['Score'].str.replace('Unknown','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\2306927867.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Action['Score'] = Action['Score'].replace(r'^\s*$', np.nan, regex=True)

# %%
Action['Name'].sample(5).values
# Out:
# array(['Starship Troopers: Red Planet', 'Chrno Crusade', 'Tide-Line Blue',
#        'Seupideuwang Beongae', 'Kyattou Ninden Teyandee'], dtype=object)

# %%
Fear['Score'] = Fear['Score'].str.replace('Unknown','')
Fear['Score'] = Fear['Score'].replace(r'^\s*$', np.nan, regex=True)
Fear = Fear.dropna()
Fear = Fear.sort_values(ascending=False,by='Score')
Surprised['Score'] = Surprised['Score'].str.replace('Unknown','')
Surprised['Score'] = Surprised['Score'].replace(r'^\s*$', np.nan, regex=True)
Surprised = Surprised.dropna()
Surprised = Surprised.sort_values(ascending=False,by='Score')
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1676\919614454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fear['Score'] = Fear['Score'].str.replace('Unknown','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1676\919614454.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fear['Score'] = Fear['Score'].replace(r'^\s*$', np.nan, regex=True)
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1676\919614454.py:5: SettingWithCopyWarning:
# ...

# %%
Comedy['Score'] = Comedy['Score'].str.replace('Unknown','')
Comedy['Score'] = Comedy['Score'].replace(r'^\s*$', np.nan, regex=True)
Comedy = Comedy.dropna()
Comedy = Comedy.sort_values(ascending=False,by='Score')
Comedy = Comedy.head(5)
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\2486020070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Comedy['Score'] = Comedy['Score'].str.replace('Unknown','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\2486020070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Comedy['Score'] = Comedy['Score'].replace(r'^\s*$', np.nan, regex=True)

# %%
Sports['Score'] = Sports['Score'].str.replace('Unknown','')
Sports['Score'] = Sports['Score'].replace(r'^\s*$', np.nan, regex=True)
Sports = Sports.dropna()
Sports = Sports.sort_values(ascending=False,by='Score')
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\3693993622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sports['Score'] = Sports['Score'].str.replace('Unknown','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\3693993622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sports['Score'] = Sports['Score'].replace(r'^\s*$', np.nan, regex=True)

# %%
Name = list(Action['Name'].sample(5).values)

# %%
Name
# Out:
# ['Digimon Adventure tri. 1: Saikai',
#  'Relic Armor Legaciam',
#  'Lupin III: Lupin vs. Fukusei-ningen',
#  'Taiyou no Yuusha Fighbird',
#  'Hand Shakers: Go ago Go']

# %%
Drama['Score'] = Drama['Score'].str.replace('Unknown','')
Drama['Score'] = Drama['Score'].replace(r'^\s*$', np.nan, regex=True)
Drama = Drama.dropna()
Drama = Drama.sort_values(ascending=False,by='Score')
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\3879442738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Drama['Score'] = Drama['Score'].str.replace('Unknown','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\3879442738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Drama['Score'] = Drama['Score'].replace(r'^\s*$', np.nan, regex=True)

# %%
Supernatural['Score'] = Supernatural['Score'].str.replace('Unknown','')
Supernatural['Score'] = Supernatural['Score'].replace(r'^\s*$', np.nan, regex=True)
Supernatural = Supernatural.dropna()
Supernatural = Supernatural.sort_values(ascending=False,by='Score')
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\1272483088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Supernatural['Score'] = Supernatural['Score'].str.replace('Unknown','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\1272483088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Supernatural['Score'] = Supernatural['Score'].replace(r'^\s*$', np.nan, regex=True)

# %%
Mecha['Score'] = Mecha['Score'].str.replace('Unknown','')
Mecha['Score'] = Mecha['Score'].replace(r'^\s*$', np.nan, regex=True)
Mecha = Mecha.dropna()
Mecha = Mecha.sort_values(ascending=False,by='Score')
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\1095892582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mecha['Score'] = Mecha['Score'].str.replace('Unknown','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\1095892582.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mecha['Score'] = Mecha['Score'].replace(r'^\s*$', np.nan, regex=True)

# %%
Romance['Score'] = Romance['Score'].str.replace('Unknown','')
Romance['Score'] = Romance['Score'].replace(r'^\s*$', np.nan, regex=True)
Romance = Romance.dropna()
Romance = Romance.sort_values(ascending=False,by='Score')
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\3478280839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Romance['Score'] = Romance['Score'].str.replace('Unknown','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\3478280839.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Romance['Score'] = Romance['Score'].replace(r'^\s*$', np.nan, regex=True)

# %%
SciFi['Score'] = SciFi['Score'].str.replace('Unknown','')
SciFi['Score'] = SciFi['Score'].replace(r'^\s*$', np.nan, regex=True)
SciFi = SciFi.dropna()
SciFi = SciFi.sort_values(ascending=False,by='Score')
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\2188539643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SciFi['Score'] = SciFi['Score'].str.replace('Unknown','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\2188539643.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SciFi['Score'] = SciFi['Score'].replace(r'^\s*$', np.nan, regex=True)

# %%
Adventure['Score'] = Adventure['Score'].str.replace('Unknown','')
Adventure['Score'] = Adventure['Score'].replace(r'^\s*$', np.nan, regex=True)
Adventure = Adventure.dropna()
Adventure = Adventure.sort_values(ascending=False,by='Score')
# Out:
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\2234152418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Adventure['Score'] = Adventure['Score'].str.replace('Unknown','')
# C:\Users\shuai\AppData\Local\Temp\ipykernel_1628\2234152418.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Adventure['Score'] = Adventure['Score'].replace(r'^\s*$', np.nan, regex=True)

# %%
import pickle

# %%
pickle.dump(Action,open('action.pickle','wb'))
pickle.dump(Romance,open('romance.pickle','wb'))
pickle.dump(Sports,open('sports.pickle','wb'))
pickle.dump(Supernatural,open('supernatural.pickle','wb'))
pickle.dump(Comedy,open('comedy.pickle','wb'))
pickle.dump(Mecha,open('mecha.pickle','wb'))
pickle.dump(SciFi,open('scifi.pickle','wb'))
pickle.dump(Drama,open('drama.pickle','wb'))
pickle.dump(Adventure,open('adventure.pickle','wb'))

# %%
pickle.dump(Sports,open('Sports.pickle','wb'))

# %%
pickle.dump(Fear,open('fear.pickle','wb'))
pickle.dump(Surprised,open('surprised.pickle','wb'))
